# %%
#This is main code for Smart_Mall
def account():
    try:
        print('enter your name')
        name=input('')
        print('enter your password')
        __passw=int(input(''))
        if(name=='abhi'):
            if(__passw==7210):
                print('''you sucessfully buyed
                 thanks abhi for come''')
            else:
                print('error in process due to wrong password')
        elif(name=='neeru'):
            if(__passw==3232):
                print('''you sucessfully buyed
                 thanks neeru for come''')
            else:
                print('error in process due to wrong password')
        elif(name=='kulli'):
            if(__passw==1051):
                print('''you sucessfully buyed
                 thanks kulli for come''')
            else:
                print('error in process due to wrong password')
        else:
            print("unknown person")
    except(ValueError):
        print('password is in number form')

        
def samsung():
    def tv():
            print('price of avilable TV are given below')
            pshirt=["1-> 2500","2-> 40000","3-> 55000"]
            print(pshirt)
            print('Select no. coresponding price')
            z=int(input(""))
            if(z==1):
                print ("you select 2500 rupees TV for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==2):
                print ("you select 40000 rupees TV for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==3):
                print ("you select 55000 rupees TV for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            else:
                print('invalid input please try again')
    def watch():
            print('price of avilable Watchs are given below')
            pshirt=["1-> 20999","2-> 15999","3-> 19998"]
            print(pshirt)
            print('Select no. coresponding price')
            z=int(input(""))
            if(z==1):
                print ("you select 20999 rupees Watch for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==2):
                print ("you select 15999 rupees Watch for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==3):
                print ("you select 19998 rupees Watch for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            else:
                print('invalid input please try again')
    def mob():
            print('price of avilable mobiles are given below')
            pshirt=["1-> 15000","2-> 20000","3-> 30000"]
            print(pshirt)
            print('Select no. coresponding price')
            z=int(input(""))
            if(z==1):
                print ("you select 15000 rupees mobile for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==2):
                print ("you select 20000 rupees mobile for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==3):
                print ("you select 30000 rupees mobile for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            else:
                print('invalid input please try again')
    while(1):
        y=0
        print('''Welcome in samsung shop
            what would you like to buy''')
        rm=['1. TV','2. Watchs','3. Mobiles','4.exit']
        print(rm)
        y=int(input(""))
        if(y==1):
            print('You select ',y,'in TV')
            tv()
        elif(y==2):
            print('you select ',y,'in WATCHS')
            watch()
        elif(y==3):
            print('you select ',y,'in MOBILES')
            mob()
        elif(y==4):
            print('thanks for visit')
            break
        else:
            print(' ',y,' is invalid input try again')
def raymond():
    def shirt():
            print('price of avilable shirts are given below')
            pshirt=["1-> 500","2-> 1000","3-> 1500"]
            print(pshirt)
            print('Select no. coresponding price')
            z=int(input(""))
            if(z==1):
                print ("you select 500 rupees shirt for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==2):
                print ("you select 1000 rupees shirt for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==3):
                print ("you select 1000 rupees shirt for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            else:
                print('invalid input please try again')
    def tshirt():
            print('price of avilable T-shirts are given below')
            pshirt=["1-> 200","2-> 500","3-> 700"]
            print(pshirt)
            print('Select no. coresponding price')
            z=int(input(""))
            if(z==1):
                print ("you select 200 rupees T-shirt for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==2):
                print ("you select 500 rupees T-shirt for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==3):
                print ("you select 700 rupees T-shirt for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            else:
                print('invalid input please try again')
    def formalpants():
            print('price of avilable Formal pants are given below')
            pshirt=["1-> 1500","2-> 2000","3-> 3000"]
            print(pshirt)
            print('Select no. coresponding price')
            z=int(input(""))
            if(z==1):
                print ("you select 1500 rupees formal pant for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==2):
                print ("you select 15000 rupees Formal pant for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            elif(z==3):
                print ("you select 3000 rupees Formal pant for buy press y and n for NO")
                za=input('')
                if(za=='y'):
                    account()
                else:
                    print("not buyed")
            else:
                print('invalid input please try again')
    while(1):
        y=0
        print('''Welcome in raymond 
              what would you like to buy''')
        rm=['1. Shirt','2. T-Shirt','3. Formal Pant','4.exit']
        print(rm)
        y=int(input(""))
        if(y==1):
            print('You select ',y,'in Shirt')
            shirt()
        elif(y==2):
            print('you select ',y,'in T-SHIRT')
            tshirt()
        elif(y==3):
            print('you select ',y,'in FORMAL PANTS')
            formalpants()
        elif(y==4):
            print('thanks for visit')
            break
        else:
            print(' ',y,' is invalid input try again')
        

while(1):
    x=0
    print('''welcome in neeru's mall
                Enter which no. shop you want to visit''')
    m=['1. Raymond','2. Samsung','3. Exit']
    print(m)
    x=int(input(""))
    if(x==1):
        print('You select ',x,'no. shop name is Raymond')
        raymond()
    elif(x==2):
        print('you select ',x,'no. shop name is Samsung')
        samsung()
    elif(x==3):
        print('thanks for visit')
        break
    else:
        print(' ',x,' is invalid input better luck next time')
# Out:
# welcome in neeru's mall
#                 Enter which no. shop you want to visit
# ['1. Raymond', '2. Samsung', '3. Exit']
# 2
# you select  2 no. shop name is Samsung
# Welcome in samsung shop
#             what would you like to buy
# ['1. TV', '2. Watchs', '3. Mobiles', '4.exit']
# 3
# you select  3 in MOBILES
# price of avilable mobiles are given below
# ['1-> 15000', '2-> 20000', '3-> 30000']
# Select no. coresponding price
# 3
# you select 30000 rupees mobile for buy press y and n for NO
# y
# enter your name
# abhi
# enter your password
# 7210
# you sucessfully buyed
#                  thanks abhi for come
# Welcome in samsung shop
#             what would you like to buy
# ['1. TV', '2. Watchs', '3. Mobiles', '4.exit']
# 5
#   5  is invalid input try again
# Welcome in samsung shop
#             what would you like to buy
# ['1. TV', '2. Watchs', '3. Mobiles', '4.exit']
# 4
# thanks for visit
# welcome in neeru's mall
#                 Enter which no. shop you want to visit
# ...

# %%
#this is another future implementing code not main code_______________
class mall:
    while(1):
        while(1):
            rup1=500
            rup2=1000
            rup3=1500
            print('''welcome in neeru's mall
            Enter which no. shop you want to visit''')
            list=['1. Raymond','2. Bikaner','3. Samsung','4. Exit']
            print(list)
            x=int(input(""))
            if(x==1):
                print('You select ',x,'no. shop name is Raymond')
            elif(x==2):
                print('you select ',x,'no. shop name is Bikaner')
            elif(x==3):
                print('you select ',x,'no. shop name is Samsung')
            elif(x==4):
                print('thanks for visit')
                break
            else:
                print(' ',x,' is invalid input better luck next time')
                break
            print('''continue with this y for YES n for NO''')
            Y=(input(""))
            if(Y=='y'):
                print('Ok, Now your list is coming....')
            elif(Y=='n'):
                print('Ok, directing you on main menu...')
                break
            else:
                print(' ',Y,' is invalid input')
            if(x==1 and Y=='y'):
                while(1):
                    print('''welcome in Raymond shop''')
                    listray=['1.Shirt','2.T-Shirt','3.Pant','4. Exit']
                    print(listray)
                    print('''Enter your choise no. ''')
                    ray=int(input(""))
                    if(ray==1):
                        print('Shirts under ',rup1,' ',rup2,' ',rup3,'want to buy enter rupee')
                        rup=(int(input(""))
                        print('Shirts under ',rup,'want to buy enter y for YES or n for NO')
                        rayp=input("")
                        if(rayp=='y'):
                            print('thanks for buy')
                        elif(rayp=='n'):
                            print('Try again')
                        else:
                            print(' ',rayp,'is invalid input try again')
                            break
                    elif()
# Out:
#   File "<ipython-input-1-f76b5435e3dc>", line 43
#     print('Shirts under ',rup,'want to buy enter y for YES or n for NO')
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #
